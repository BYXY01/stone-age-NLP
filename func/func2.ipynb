# %% [markdown]
# # 功能模块 func (架构2 的功能：V2.1 / V2.5)

# %% [markdown]
# 本 Notebook 承载架构 2 之上的功能扩展，对应 func 包的 features 模块。
#
# SPDX-License-Identifier: MIT

# %% [markdown]
# ## 依赖导入

# %%
import arch.core as core
from arch.core import (fenci, tongji, tongji2, jiaquan1, jiaquan2,
                       jiaquan_output_test1, jiaquan_output_test2,
                       word_dic, word_dic_2, word_dic_3, repl)
import re

# %% [markdown]
# ## test2_1 —— 电子鹦鹉（记忆版）

# %%
# 每次用户输入统计，尝试带记忆
def jiaquan_output_test1_1(words,ignor_words=''):
    tongji(words)
    tongji2(words)
    jiaquan_output_test1(words,ignor_words)

# %% [markdown]
# ## test2_5 —— 联网版

# %%
# 增加外部资料添加到统计

def jiaquan_output_test1_fix(words,ignor_words=''):
    lst=[]
    lst.extend(words)
    print(*words,sep='',end='')
    while lst[-1] != repl:
        jiaquan_res=jiaquan1(lst,word_dic,word_dic_2)
        while jiaquan_res[0][0] in ignor_words or jiaquan_res[0][0] in lst:
            jiaquan_res.pop(0)
        new_word=jiaquan_res[0][0]
        lst.append(new_word)
        print(new_word,end='')
    print()
    return lst

def jiaquan_output_test1_5(words,Ref_Data,ignor_words=''):
    def Proces_Ref_Data():
        result=""
        if type(Ref_Data) is type(list()):
            for i_str in Ref_Data:
                no_sign_i_str=re.sub(r'\W', '', i_str)
                result+=(no_sign_i_str+'_')
        if type(Ref_Data) is type(str()):
            result=Ref_Data+'_'
        # return result
        return fenci(result)
    tongji(Proces_Ref_Data())
    tongji2(Proces_Ref_Data())
    try:
        jiaquan_output_test1_fix(words,ignor_words)
    except:
        jiaquan_output_test1_fix(words+['_'], ignor_words)
