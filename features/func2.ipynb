# %% [markdown]
# # Features · func2 (architecture 2's extras: V2.1 / V2.5)

# %% [markdown]
# This notebook carries the feature extensions on top of architecture 2,
# mapping to the `features` package modules.
#
# SPDX-License-Identifier: MIT

# %% [markdown]
# ## dependencies

# %%
import core.core as core
from core.core import (bigram_counts, cooccurrence_counts, count_bigrams, generate,
                       split_words, weighted_score, SEP)
import re

# %% [markdown]
# ## test2_1 — V2.1 electronic parrot (memory)

# %% [markdown]
# Memory: every user utterance updates the statistics on the fly — the parrot learns as it goes.

# %%
"""V2.1: memory — every user utterance updates the statistics on the fly."""



def generate_with_memory(words, ignore_words=''):
    """Predict after feeding the current utterance into the statistics (learns as it goes)."""
    count_bigrams(words)
    count_cooccurrence(words)
    generate(words, ignore_words)

# %% [markdown]
# ## test2_5 — V2.5 web version

# %% [markdown]
# Web: inject external search results into the statistics — the parrot that looks things up.

# %%
"""V2.5: web — inject external search results into the statistics."""

import re



def generate_no_repeat(words, ignore_words=''):
    """Like ``generate``, but never repeats a word already generated."""
    lst = list(words)
    print(' '.join(lst), end='')
    while lst[-1] != SEP:
        ranked = weighted_score(lst, bigram_counts, cooccurrence_counts)
        while ranked[0][0] in ignore_words or ranked[0][0] in lst:
            ranked.pop(0)
        new_word = ranked[0][0]
        lst.append(new_word)
        print(' ' + new_word, end='')
    print()
    return lst


def generate_with_reference(words, ref_data, ignore_words=''):
    """Predict using extra reference data (e.g. web search results)."""

    def process_reference():
        if type(ref_data) is type(list()):
            return split_words(' '.join(re.sub(r'\W', ' ', item) for item in ref_data))
        if type(ref_data) is type(str()):
            return split_words(ref_data)
        return []

    processed = process_reference()
    count_bigrams(processed)
    count_cooccurrence(processed)
    try:
        generate_no_repeat(words, ignore_words)
    except Exception:
        generate_no_repeat(words + [SEP], ignore_words)
